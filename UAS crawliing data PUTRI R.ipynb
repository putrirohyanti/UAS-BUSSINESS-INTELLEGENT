# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
Consumer_Key = "7QR7t13SCnk9NqsZfsxA7TLWG"
Consumer_Secret_Key = "UG5fMtsvhfed60Ph8x3XioOMI6GZoc1PVp1xOrOvyU4P7ZkoUI"
Access_Token = "1169119459400978435-AFfZGZbq2pPUS0kfDwOOM8tFd2amR3"
Access_Token_Secret = "kx12HUgzobDE89Iqd1gNG1r2cpfBW5oReWR1rgFFqXC3I"

# %%
auth = tweepy.OAuthHandler(Consumer_Key,Consumer_Secret_Key)
auth.set_access_token(Access_Token,Access_Token_Secret)
api = tweepy.API(auth)

# %%
posts = api.user_timeline(screen_name="Tokopedia", count = 1000,  lang = "en", tweet_mode = "extended")

#print the last 20 tweets
print ("Show the 20 recent tweets:\n")
i=1
for tweet in posts[:20]:
  print(str(i) + ')'+ tweet.full_text + '\n')
  i=i+1
# Out:
# Show the 20 recent tweets:
#
# 1)GIVEAWAY                          GIVEAWAY
# ALBUM                                LIGHTSTICK https://t.co/wuccKsQZU1
#
# 2)Belanja elektronik harga bersahabat,
# bikin kerja jadi makin giat!
# Ada diskon hingga 60% dan cashback hingga 200ribu
#
# Cek di sini:
# https://t.co/DJZMMNpWzo https://t.co/nwduAYeTII
#
# 3)Di rumah aja tetap gaya dengan fashion terbaru yang bisa kamu dapatkan dengan cashback hingga Rp70Rb. Temukan gaya favoritmu di https://t.co/2KblBLyiEh
# _
# #Fashion
#
# 4)Masker Case + Free Bottle - Rp64.900
# https://t.co/4oILKsKy26 https://t.co/lUJWCMrCOD
#
# 5)masker Case Motif - Rp30.000
# https://t.co/HZomjbkdES https://t.co/mNZzlzG65U
#
# 6)Masker Case N95 - Rp45.000
# https://t.co/LilQ6g2AaO https://t.co/bKVNpVBwwU
#
# 7)Masker Case Motif Kartun - Rp15.000
# https://t.co/DSLsSiNQ0m https://t.co/U5uOUCu7D2
#
# 8)Masker Case - Rp15.900
# https://t.co/snH1DUIHQh https://t.co/tYSLgFQdb4
#
# 9)Masker Case - Rp15.000
# https://t.co/Y8zdSnOK0K https://t.co/1lsbW0BJwz
#
# 10)Masker case - Rp.11.000
# https://t.co/WhZPVdl2cN https://t.co/UnsMGsflAi
#
# 11)Masker Ziplock - Rp9.800
# https://t.co/dzEL0VCJI5 https://t.co/06ixXcoYaM
#
# 12)Masker Case Design Unik, Simple, lucu lucu, harga mulai dari 10ribu
# .
# .
# .
# .
# A THREAD (Save now or cry later) https://t.co/YgWAvOvmUr
#
# 13)Ayo apa? https://t.co/8ZqvUYETKq
#
# 14)Banyak pilihan gadget yang smart di era serba cepat! Yuk belanja di Gadget on Tuesday dan dapatkan Diskon hingga 70% + Cashback hingga 170RB! Klik &gt;
# https://t.co/Yp8Fuuobr9
# #HPGadget #GOT
#
# 15)DROP YOUR FAVORITE GIF HEREEE
#
# 👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻
#
# 16)@rofidabyan1111 Selamat Tahun Baru 2021, Kak Rofidabyan! Semoga sehat dan bahagia selalu ya Kak! Kami sudah mengirimkan pesan ke Kakak melalui Direct Message (DM) ya Kak. Mohon kesediaan Kakak untuk mengecek DMnya. Kami tunggu balasannya.
#
# 17)Apa lagu terakhir yang kamu dengar?
#
# Buat kamu pengguna JOOX, ADA diskon 30%! Kuota terbatas, klik gambar di bawah
#
# 18)Throwback performance KING NASSAR di #TokopediaWIB TV SHOW bulan lalu! Siapa yang kangennnn??? Happy birthday juga yaa buat King Nassar🥰👑👑🥰
#
# #KINGNASSARDAY https://t.co/CFs7xl8Qe2
#
# 19)Jika kamu ikutan #TokopediaWIB TV SHOW pilih nonton artis favorit kamu perform atau ikutan mereka interview bareng Mas Hansol ??
#
# 20)Cuci Gudang produk terlaris sampai habis! Dapatkan Diskon hingga 90% + Cashback hingga Rp 100RB. Klik linknya &gt;
# https://t.co/Dd1zqGbQid
# #HomeNLiving #HLS

# %%
df = pd.DataFrame([tweet.full_text for tweet in posts], columns=['Tweets'])
# Show the first 5 rows of data
df.head()
# Out:
#                                               Tweets
# 0  GIVEAWAY                          GIVEAWAY\nAL...
# 1  Belanja elektronik harga bersahabat,\nbikin ke...
# 2  Di rumah aja tetap gaya dengan fashion terbaru...
# 3  Masker Case + Free Bottle - Rp64.900\nhttps://...
# 4  masker Case Motif - Rp30.000\nhttps://t.co/HZo...

# %%
def cleanTxt(text):
  text = re.sub('@[A-Za - z0-9]+', '', text) #Removing @mentions
  text = re.sub('#', '', text) #Removing '#' has tag
  text = re.sub('RT[\s]+', '', text) #Removing RT
  text = re.sub('https?:\/\/\s+', '', text) #Removing hyperlink
  text = re.sub(r"[-()\"#/@;:<>{}-=~|.?,]","",text)
  text = re.sub(r"can't","cannot",text)
  text = re.sub("\'\w+", '', x)
  return text

  #clean the tweets
  df['Tweets'] = df['Tweets'].apply(cleanTxt)

  #show the cleaned tweets
  df

# %%
#creat a function to get the subjectivity
def getSubjectivity(text):
  return TextBlob(text).sentiment.subjectivity

#creat a function to get the polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

#creat two new columns 'Subjectivity' & 'Polarity'
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

#show the new dataframe with columns 'Subjectivity' & 'Polarity'
df
# Out:
#                                                 Tweets  Subjectivity  Polarity
# 0    GIVEAWAY                          GIVEAWAY\nAL...           0.0       0.0
# 1    Belanja elektronik harga bersahabat,\nbikin ke...           0.0       0.0
# 2    Di rumah aja tetap gaya dengan fashion terbaru...           0.0       0.0
# 3    Masker Case + Free Bottle - Rp64.900\nhttps://...           0.8       0.4
# 4    masker Case Motif - Rp30.000\nhttps://t.co/HZo...           0.0       0.0
# ..                                                 ...           ...       ...
# 195  Yang hobi baca buku mana suaranya? Kamu bisa d...           0.0       0.0
# 196  Dear 2021 semoga aku lebih sering checkout bar...           0.0       0.0
# 197  Pagi! Siapa nih artis favorit kamu selama #Tok...           0.0       0.0
# 198  Lagi nyari kebutuhan kendaraan di akhir tahun?...           0.0       0.0
# 199  RT @TokopediaCare: MY DAY! Masih ada 2 Officia...           0.0       0.0
#
# [200 rows x 3 columns]

# %%
#word cloud visualization
allWords = ' '.join([twts for twts in df['Tweets']])
wordCloud = WordCloud(width=500, height=300, random_state=10, max_font_size=110).generate(allWords)

plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#create a function to compute negative (-1), neutral (0) and positive (+1) analysis
def getAnalysis(score):


  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'
df ['Analysis'] = df['Polarity'].apply(getAnalysis)
#show the dataframe
df
# Out:
#                                                 Tweets  ...  Analysis
# 0    GIVEAWAY                          GIVEAWAY\nAL...  ...   Neutral
# 1    Belanja elektronik harga bersahabat,\nbikin ke...  ...   Neutral
# 2    Di rumah aja tetap gaya dengan fashion terbaru...  ...   Neutral
# 3    Masker Case + Free Bottle - Rp64.900\nhttps://...  ...  Positive
# 4    masker Case Motif - Rp30.000\nhttps://t.co/HZo...  ...   Neutral
# ..                                                 ...  ...       ...
# 195  Yang hobi baca buku mana suaranya? Kamu bisa d...  ...   Neutral
# 196  Dear 2021 semoga aku lebih sering checkout bar...  ...   Neutral
# 197  Pagi! Siapa nih artis favorit kamu selama #Tok...  ...   Neutral
# 198  Lagi nyari kebutuhan kendaraan di akhir tahun?...  ...   Neutral
# 199  RT @TokopediaCare: MY DAY! Masih ada 2 Officia...  ...   Neutral
#
# [200 rows x 4 columns]

# %%
print('Printing negative tweets:\n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if ( sortedDF['Analysis'][i] == 'Negative'):
    print(str(j)+ ')' +sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# Printing negative tweets:
#
# 1)Hai, Ibu-ibu, pas suami asyik main game atau sibuk sendiri sama hobi mereka, mending belanja alat-alat dapur di Karnaval Dapur.
# Klik link ini https://t.co/09se4xBIod ! Yuk BuIbu buruan diserbu! Mimin nitip yaa buat di kost-an 😆😆
# #HomeNLiving #KarnavalDapur
#
# 2)@ryang_aja Estetik banget siah alas pancinya! 😎

# %%
print('Printing positive tweets:\n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=True) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if ( sortedDF['Analysis'][i] == 'Positive'):
    print(str(j)+ ')' +sortedDF['Tweets'][i])
    print()
    j=j+1
# Out:
# Printing positive tweets:
#
# 1)Masker Case + Free Bottle - Rp64.900
# https://t.co/4oILKsKy26 https://t.co/lUJWCMrCOD
#
# 2)Banyak pilihan gadget yang smart di era serba cepat! Yuk belanja di Gadget on Tuesday dan dapatkan Diskon hingga 70% + Cashback hingga 170RB! Klik &gt;
# https://t.co/Yp8Fuuobr9
# #HPGadget #GOT
#
# 3)DROP YOUR FAVORITE GIF HEREEE
#
# 👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻👇🏻
#
# 4)@rofidabyan1111 Selamat Tahun Baru 2021, Kak Rofidabyan! Semoga sehat dan bahagia selalu ya Kak! Kami sudah mengirimkan pesan ke Kakak melalui Direct Message (DM) ya Kak. Mohon kesediaan Kakak untuk mengecek DMnya. Kami tunggu balasannya.
#
# 5)Throwback performance KING NASSAR di #TokopediaWIB TV SHOW bulan lalu! Siapa yang kangennnn??? Happy birthday juga yaa buat King Nassar🥰👑👑🥰
#
# #KINGNASSARDAY https://t.co/CFs7xl8Qe2
#
# 6)BREAKING NEWS LAINNYA 📺 LIVE dari Tokopedia Tower!
# Setiap hari Selasa di bulan Januari bakal ada Gadget on Tuesday (GOT) Quiz berhadiah di IG Story Tokopedia!
# JANGAN SAMPAI KETINGGALAN 🤩🤩
# #HPGadget #GadgetOnTuesday #Quiz #KuisIndonesia #KuisGiveaway
#
# 7)Selamat pagi dari hari Senin pertama di 2021 :)
#
# 8)@annoyyyouuu Aminn 🙏🏼 Good luck! 🍀
#
# 9)New Year New Me! Tiap tahun punya resolusi yang sama! Siapa yang gini juga? 😝
#
# Share ke mimin dong resolusi kamu tahun 2021, masih sama kayak tahun-tahun sebelumnya gak? https://t.co/HulNOAwwcA
#
# 10)Yuk Top Up mTix mu sekarang dan dapatkan voucher diskon 10rb buat tiket nonton dan makanan kamu! Info selanjutnya, klik https://t.co/1t6jOhcdJD
#
# 11)2. Si tukang borong aksesoris tahun baru - bando, kacamata, pokoknya mereka yang paling lengkap &amp; excited deeh soal iniii https://t.co/6FjL0ds0vw
#
# 12)1. “The new year new me” type, sibuk nyusun resolusi (dan biasanya juga lagi nge plan mau potong rambut model gimana, supaya ✨new me✨ nya kerasa 😂) Ayoloooh siapa yg giniii 😋😋 https://t.co/jC9wjsGYcY
#
# 13)@mintzlicious WOW! +1855% !!!!
#
# 14)Hari Rabu waktunya belanja kebutuhan kenndaraan kamu. Karena ada promo Rabu Ngebut yang bikin belanjamu super hemat. Klik https://t.co/LdjQ0ChvEX
#
# #otomotif
#
# 15)@febrianiblink wahhh bole jugaa nih buat bersihin AC kamar mimin. thanks for sharing!
#
# 16)@sundarafa Enak yaaa gak perlu pompa lagi lengan jadi berotot bund :))

# %%
plt.figure(figsize=(8,6))
for i in range(0, sortedDF.shape[0] ):
  plt.scatter(df["Polarity"][i],df["Subjectivity"][i],color='Blue')
  #plt.scatter(x,y,color)
  plt.title('Sentiment Analysis')
  plt.xlabel('Polarity')
  plt.ylabel('Subjectivity')
  plt.show()

# %%
ptweets = df[df.Analysis == 'Positive']
ptweets = ptweets['Tweets']
ptweets

round( (ptweets.shape[0] / df.shape[0]) * 100 , 1)
# Out:
# 8.0

# %%
ntweets = df[df.Analysis == 'Negative']
ntweets = ntweets['Tweets']
ntweets

round( (ntweets.shape[0] / df.shape[0]) * 100 , 1)
# Out:
# 1.0

# %%
#show the value counts
df['Analysis'].value_counts()
# Out:
# Neutral     182
# Positive     16
# Negative      2
# Name: Analysis, dtype: int64

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind = 'bar')
plt.show()

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind = 'line')
plt.show()

# %%
public_tweets = api.search(q=['Tokopedia','Shopee'], count=50)

# %%
all_polarity = 0
for tweet in public_tweets:
  print(tweet.text)
  #step 3 - Perform Sentiment Analysis On Tweets
  analysis = TextBlob(tweet.text)
  an =  analysis.translate(from_lang='id',to='en')
  print(an.sentiment)
  all_polarity += an.polarity

  print("")
# Out:
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @Aldhichandras: Bismillah untung menyambung hidup mau jualan kaos polos bahan cotton combed 30s.
# sudah ada di tokped https://t.co/tFBW9i…
# Sentiment(polarity=-0.007142857142857131, subjectivity=0.2285714285714286)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# Tautan pemesanan untuk buku EON:
# Shopee: https://t.co/KfDjPS49dU
# Tokopedia: https://t.co/VB6hSeT7W7
# WhatsApp: 08138… https://t.co/o2rvIsSHGz
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Bismillah untung menyambung hidup mau jualan kaos polos bahan cotton combed 30s.
# sudah ada di tokped… https://t.co/XGaEwQwur9
# Sentiment(polarity=0.1285714285714286, subjectivity=0.3857142857142857)
#
# @GubjenVOC Academia, research gate nek gak coba gae searchkey b. Ing, lek gaono inspirsi coba shopee pdf, tokopedia pdf etc
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# Secara fitur Tokopedia emang kalah jauh sama Shopee. UI/UX sih tergantung selera masing2 orang ya, tapi 2021 compla… https://t.co/Hq8BnfE1Fj
# Sentiment(polarity=-0.03333333333333335, subjectivity=0.6333333333333333)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# @JUALAN_BASE Nitippp. Daisy bisa satuan dan grosiran ya😉
# Shopee : https://t.co/2PiU64ae1C
# Tokopedia :… https://t.co/fSefvZlVOj
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @PenerbitPrabu21: Temukan buku-buku terbitan kami di toko online berikut :
# Shopee :https://t.co/nGeK0K5q6H
# Tokopedia :https://t.co/udBXu…
# Sentiment(polarity=0.0, subjectivity=0.1)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @KoepoeKoepoeID: Dear  Sahabat Koepoe,
# Koepoe Koepoe  Official Store Shopee, Tokopedia, dan https://t.co/MXaqxzgGr8 libur dari tanggal 2…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @moonfairyies: tokopedia. tp gua pake shopee.
# bank bukopin. tp gua pake bri.
# samsung. tp gua pake vivo.
# coca-cola. tp gua sukanya sprite…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @jek___ Mumpung rame mau titip jualan hehe
#
# Hi Teman Minimall✨
#
# Aku jual berbagai macam hoodie/sweatshirt H&amp;M or… https://t.co/8rZ3WGS5sf
# Sentiment(polarity=0.2, subjectivity=0.1)
#
# Tahun baru semangat baru! 🎉
#
# WiFi Turki dari Travel Recommends menyediakan internet internasional berkecepatan 4G y… https://t.co/pc7CmSEYlt
# Sentiment(polarity=0.10227272727272725, subjectivity=0.30303030303030304)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @moonfairyies: tokopedia. tp gua pake shopee.
# bank bukopin. tp gua pake bri.
# samsung. tp gua pake vivo.
# coca-cola. tp gua sukanya sprite…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @Mirongtea Hahaha kakkk 🤗
# Untuk varian baru yang ini belum launch kak tapi untuk 5 varian lain nya kakak bisa beli… https://t.co/OKhUnySwyb
# Sentiment(polarity=0.07045454545454545, subjectivity=0.40984848484848485)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @duabelibis: Dear  Eaters,
# Dua Belibis  Official Store Shopee, Tokopedia, Bukalapak dan https://t.co/GVWBptSxUI libur dari tanggal 29 De…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @duabelibis: Kamu bisa belanja di Dua Belibis Official Shop : Tokopedia, Shopee, Bukalapak, dan https://t.co/GVWBptSxUI. Go check ya dan…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Bismillah...
#
# D'Mamam, frosen food sehat masih ready stock di Tokopedia dan Shopee kami. Yuks order, tinggal klik l… https://t.co/3cQvCqWsiB
# Sentiment(polarity=0.35, subjectivity=0.5)
#
# RT @moonfairyies: tokopedia. tp gua pake shopee.
# bank bukopin. tp gua pake bri.
# samsung. tp gua pake vivo.
# coca-cola. tp gua sukanya sprite…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# Tokopedia. tapi aku pake shopee
# Bank bukopin. tapi aku pake bri
# Samsung. tapi aku pake vivo
# Coca-cola. tapi aku suka sprite
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @ArizkyPrima: Kamu Masih jadi reseller?..
# Kini saatnya kamu jadi distributor supaya margin kamu lebih untung!!
# Yuk gabung dengan kami. U…
# Sentiment(polarity=0.78125, subjectivity=0.5)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# Oh yaa, selain bisa dibeli di Watson, ini juga ada di Official Store SNP di Shopee, Tokopedia, Sociolla, dan marketplace lain. Cek deh ❤️❤️
# Sentiment(polarity=0.25833333333333336, subjectivity=0.4666666666666666)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @bukugpu: Sobat introver &amp; mager, buku wajib kita sedang ditandatangani penulisnya @rinilucia sebentar lagi dikirim. 🎁 PO-nya masih berl…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# 2. Belanja online
#
# Jaman udah maju kok masih belanja offline? eCommerce? Gak masalah.
#
# Usahakan pencarian pertama d… https://t.co/p526KzSLwQ
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
#
# Shopee or tokopedia ???
# It’s more easier if one of the shops have this PO 💆🏻‍♀️ https://t.co/iuUOSEwYVR
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# Sobat introver &amp; mager, buku wajib kita sedang ditandatangani penulisnya @rinilucia sebentar lagi dikirim. 🎁 PO-nya… https://t.co/14TzgbpqHq
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# READY STOCK
#
# Official Adidas Bayern Munchen Face Mask Original BNWT
#
# Our price IDR 99.000
#
# #masker4sale #MiaSanMia… https://t.co/tz3lD74LYf
# Sentiment(polarity=0.2875, subjectivity=0.625)
#
# @kring_pajak Iya pkp dan bkp.hanya selama ini FP yang dibuka bukan digunggung.kalo penjualan melalui tokopedia,shop… https://t.co/DBwgTXClE8
# Sentiment(polarity=0.03333333333333333, subjectivity=0.6666666666666666)
#
# RT @Strategi_Bisnis: Rencana merger Tokopedia x Gojek ini sgra akan direalisasikan.
#
# Kombinasi tokpek x gojek x gopay mungkin cukup powerf…
# Sentiment(polarity=0.3, subjectivity=1.0)
#
# RT @ArizkyPrima: Kamu Masih jadi reseller?..
# Kini saatnya kamu jadi distributor supaya margin kamu lebih untung!!
# Yuk gabung dengan kami. U…
# Sentiment(polarity=0.78125, subjectivity=0.5)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# RT @Strategi_Bisnis: Tokopedia hadir th 2009
# Bukalapak 2010.
# Lazada 2012.
# Shopee 2015 (paling akhir)
#
# Trafik bulanan terkini :
#
# Shopee 96 j…
# Sentiment(polarity=0.16666666666666666, subjectivity=0.3333333333333333)
#
# READY STOCK
#
# Adidas Human Race Manchester United Size S &amp; L Original BNWT
#
# IDR 1.099.000
#
# #jersey4sale
#
# Order Via W… https://t.co/G34a3cjZMt
# Sentiment(polarity=0.19166666666666665, subjectivity=0.45)
#
# READY STOCK
#
#  PSG x Jordan White 2018-19 VAPORKNIT Size XXL BNWT
#
# Now only IDR 1.199.000
#
# #Jersey4Sale Order Via… https://t.co/G95hQu6kBo
# Sentiment(polarity=0.06666666666666667, subjectivity=0.5)
#
# Ekstrak Buah Mengkudu #ObatStroke Morici De Nature
#
# DAPATKAN SEKARANG (BISA COD)
# ① AGEN:
# https://t.co/m4PTZYAjAJ
# ②… https://t.co/gp8ID7kPW8
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
#To Check Positive Or Negative Sentiment From Overall Tweets
if (all_polarity/100 > 0):
  print(all_polarity/100)
  print("")
  print("Positive")

else : 
  print(all_polarity/100)
  print("")
  print("Negative")
# Out:
# 0.09260822510822507
#
# Positive
